# %%
import socket
import pickle
import struct
import cv2
import numpy as np
import os
import torch
import time
from ultralytics import YOLO
from tensorflow.keras.models import load_model

model = YOLO('yolov8s.pt', 'YOLO8.yaml')

# 저장된 가중치 파일 로드
#loaded_weights = torch.load('YOLO8_trained_model1118.pt')
loaded_weights = torch.load('YOLO8_trained_weights0517.pt')
# 모델에 state_dict 로드
model.load_state_dict(loaded_weights)

os.environ["CUDA_VISIBLE_DEVICES"]="0"  

def send_data(data):
    client_socket.send(data.encode()) # 기본자세로 다시 옮김
    time.sleep(0.01) # 0.01초 대기

# %%
#2024/11/20
client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
host_ip = '서버 주소'     # 서버 IP 주소
port = 1111                  # 포트
client_socket.connect((host_ip, port))

data = b""                # 데이터를 바이트 형식으로 받기
payload_size = struct.calcsize("Q")
class_names = {0: 'tom_flower', 1: 'truss', 2: 'stem'}    # 3개의 클래스 0 : 만개꽃, 1 : 화방, 2 : 줄기


# 미리 초기화를 해야하는 변수들
phase_num = 0      # 페이즈 제어 변수
control_num = 0    # 종합정인 제어 변수
truss_control = 0   # 화방 개수 변수
truss_coordinate = 0  # 화방 개수에 따른 위치 조정 변수
flower_control = 0   # 만개꽃 페이즈 개수 변수
noflower_count = 0   # 만개꽃 개수 카운트 변수, 2개이상 충족이 안될경우 다른 쪽으로 넘김
final_truss_num = 0
truss_num_is_0 = 0
truss_num_is_1 = 0
truss_num_is_2 = 0
final_up_down = 0
false_truss_detect = 0

while True:
    # 프레임 수신
    while len(data) < payload_size:
        packet = client_socket.recv(4*1024)  # 4K
        if not packet: break
        data += packet
    if not data: break
    packed_msg_size = data[:payload_size]
    data = data[payload_size:]
    msg_size = struct.unpack("Q", packed_msg_size)[0]
    
    while len(data) < msg_size:
        data += client_socket.recv(4*1024)

    frame_data = data[:msg_size]
    data = data[msg_size:]
    frame = pickle.loads(frame_data)
    frame = cv2.resize(frame, (640, 480))
    result = model(frame, conf=0.3, iou=0.5)

    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    img = np.transpose(img, (2, 0, 1))
    img_tensor = torch.from_numpy(img).unsqueeze(0).float()
    img_tensor /= 255.0

    with torch.no_grad():
        results = model(img_tensor)
    
    # 바운딩 박스 컬러 설정
    class_colors = {'tom_flower': (255, 0, 0), 'truss': (0, 255, 0), 'stem': (0, 0, 255) }
    
    # 감지하면 찾을 객체들
    detected_objects = {'boxes': [], 'classes': [], 'scores': [] }

        
    for i, result in enumerate(results):
        
        # 프레임 처리 시작 시 객체 정보들 초기화, 프레임마다 객체를 초기화 해서 찾아야 하기 때문에 진행
        tom_flower_num = 0  #만개꽃 개수 증가
        truss_num = 0

        tom_stem = []       # 탐지마다 갱신되는 줄기 
        tom_truss = []      # 탐지마다 갱신되는 화방
        tom_flowers1 = []   # 1화방 중심과 가장 가까운 만개꽃들
        tom_flowers2 = []   # 2화방 중심과 가장 가까운 만개꽃들

        # NMS를 위한 바운딩 박스와 신뢰도 저장
        boxes = []
        scores = []
        classes = []

        for box, cls in zip(result.boxes.xyxy, result.boxes.cls):
            x1, y1, x2, y2 = box.cpu().numpy()
            class_index = int(cls.cpu())
            score = result.boxes.conf[i].cpu().numpy().item()

            boxes.append([x1, y1, x2, y2])
            scores.append(score)
            classes.append(class_index)

        # NMS 적용
        indices = cv2.dnn.NMSBoxes(boxes, scores, score_threshold=0.3, nms_threshold=0.4)

        for index in indices:
            index = index[0]  # index는 2D 배열로 반환되므로 첫 번째 요소를 가져옴
            box = boxes[index]
            class_index = classes[index]
            score = scores[index]

            # 바운딩 박스 좌표
            x1, y1, x2, y2 = box

            class_name = class_names.get(class_index, 'Unknown')
            color = class_colors.get(class_name, (255, 255, 255))

            # 바운딩 박스 그리기
            start_point = (int(x1), int(y1))
            end_point = (int(x2), int(y2))
            thickness = 2
            cv2.rectangle(frame, start_point, end_point, color, thickness)

            # 클래스 이름과 신뢰도 표시
            label = f'{class_name}: {score:.2f}'
            cv2.putText(frame, label, (int(x1), int(y1)-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

            # 객체 정보를 리스트에 추가
            detected_objects['boxes'].append((x1, y1, x2, y2))
            detected_objects['classes'].append(class_name)
            detected_objects['scores'].append(score)

            
            if class_index == 2:    # 줄기 처리
                stem_info = {
                    'y_center': y_center,
                    'x_center': x_center,
                    'box': (x1, y1, x2, y2),
                    'class_index': class_index,
                }
                tom_stem.append(stem_info)                 # tom_stem 리스트에 추가
                tom_stem.sort(key=lambda x: x['y_center'], reverse=True) # tom_stem 리스트 y좌표 낮은 순으로 정렬
            
            
            if class_index == 1:    # 화방 처리
                truss_info = {
                    'y_center': y_center,
                    'x_center': x_center,
                    'box': (x1, y1, x2, y2),
                    'class_index': class_index,
                }
                tom_truss.append(truss_info)                # tom_truss 리스트에 추가
                tom_truss.sort(key=lambda x: x['y_center'], reverse=True) # tom_truss 리스트 y좌표 낮은 순으로 정렬
                truss_num += 1                              # 화방당 개수 증가
                

            if class_index == 0:    # 만개꽃 처리
                flower_info = {
                    'y_center': y_center,
                    'x_center': x_center,
                    'box': (x1, y1, x2, y2),
                    'class_index': class_index,
                }
                tom_flowers1.append(flower_info)  # tom_flowers1 리스트에 추가
                tom_flowers2.append(flower_info)  # tom_flowers2 리스트에 추가
                tom_flower_num += 1               # 만개꽃 개수 증가

                # 이번 프레임에서 만개꽃이 2개이상 검출되었고, 화방이 있으며 1화방과 가까운 순으로 정렬 
                flower_in_truss1 = []
                if len(tom_truss) > 0 and len(tom_flowers1) > 0:
                    truss1_box = tom_truss[0]['box']  # tom_truss[0]의 바운딩 박스
                    for flower in tom_flowers1:
                        # 만개꽃의 중심좌표가 tom_truss[0]의 바운딩 박스 내에 있는지 확인
                        if truss1_box[0] <= flower['x_center'] <= truss1_box[2] and truss1_box[1] <= flower['y_center'] <= truss1_box[3]:
                            flower_in_truss1.append(flower)  # 조건을 만족하는 만개꽃을 flower_in_truss1에 추가
                
                # tom_truss[1]의 바운딩 박스 내에 있는 tom_flowers2의 만개꽃 중심좌표를 기준으로 필터링
                flower_in_truss2 = []
                if len(tom_truss) > 1 and len(tom_flowers2) > 0:
                    truss2_box = tom_truss[1]['box']  # tom_truss[1]의 바운딩 박스
                    for flower in tom_flowers2:
                        # 만개꽃의 중심좌표가 tom_truss[1]의 바운딩 박스 내에 있는지 확인
                        if truss2_box[0] <= flower['x_center'] <= truss2_box[2] and truss2_box[1] <= flower['y_center'] <= truss2_box[3]:
                            flower_in_truss2.append(flower)  # 조건을 만족하는 만개꽃을 flower_in_truss2에 추가


#======================================== 시스템시작, phase_num == 0은 주행 페이즈 =============================================================    
        
        if(phase_num == 0):     
            print("phase_num = ", phase_num)
            if len(tom_stem) > 0 and tom_stem[0] is not None and (tom_stem[0]['x_center']>=250 and tom_stem[0]['x_center']<=350):
                control_num += 1
                if(control_num > 2):  # 프레임 내 줄기가 중앙에 완전히 위치했다 판단하는 경우, 페이즈 넘버 1로 전환
                    send_data("1")    # 데이터 1 전송
                    phase_num = 1
                    control_num=0

#========================================  화방 정보 분석 페이즈 ==============================================================================

        elif(phase_num == 1):    
            control_num += 1
            # 프레임당 검출된 화방개수를 판단하기 위해 검출된 화방 수에 따라서 truss_is_num_n에 추가되는 수가 달라짐
            if(truss_num==0):         # 화방 개수 0
                truss_num_is_0 += 1   
            elif(truss_num==1):       # 화방 개수 1
                truss_num_is_1 += 1
            elif(truss_num>=2):       # 화방 개수 2개 이상
                truss_num_is_2 += 1

            # 프레임마다 화방이 몇개 검출되었는지 확인하는 코드 
            print("phase_num = ", phase_num)
            print("truss_num_is_0 = ", truss_num_is_0)  
            print("truss_num_is_1 = ", truss_num_is_1)
            print("truss_num_is_2 = ", truss_num_is_2)
            print("control_num = ", control_num)


            # 화방개수가 2개를 충족하지 못하는 경우 팔을 올려 화방을 확인한다.
            if(control_num%30 == 29):
                print("2화방을 모두 찾을때까지 팔을 계속 올립니다. ", control_num%29)
                send_data("4")    # 데이터 9 전송
                print("UP")


            if(truss_num_is_2 >= 15):
                print("최종 화방은 2개")
                final_truss_num = 2     # 이번 사이클은 화방이 2개라 생각하고 진행
                flower_control = 1      # flower_control = 0이면 만개꽃 개수 판단때, 1화방만 있다고 생각함
                send_data("1")          # 정자세로 돌리기위해 데이터 1 전송
                phase_num = 3           # 화방 위치 조정으로 들어감
                control_num = 0

            if(truss_num_is_2 < 15 and truss_num_is_1 >= 280):
                print("최종 화방은 1개")
                final_truss_num = 1     # 이번 사이클은 화방이 2개라 생각하고 진행
                flower_control = 0      # flower_control = 0이면 만개꽃 개수 판단때, 1화방만 있다고 생각함
                send_data("1")          # 정자세로 돌리기위해 데이터 1 전송
                phase_num = 3           # 화방 위치 조정으로 들어감
                control_num = 0

            if(truss_num_is_0 > 300):
                print("최종 화방은 0개")
                final_truss_num = 0     # 이번 사이클은 화방이 0개라 생각하고 진행
                send_data("1")          # 정자세로 돌리기위해 데이터 1 전송
                phase_num = 10          # 페이즈 10으로 돌아감
                control_num = 0

        
#====================================================== 화방 좌우, 높이 조정 페이즈 ============================================================
        
        elif(phase_num == 3):    
            control_num += 1
            print("truss_coordinate = ", truss_coordinate)
            print("phase_num = ", phase_num)
            print("len(tom_truss) = ",len(tom_truss))
            
            # 1화방을 찾지 못한 경우 false_truss_detect을 증가하고, 이걸 5의 배수마다 확인하면 UP을 해 로봇팔을 위로 올림
            if(truss_coordinate == 0 and len(tom_truss) <= 0):
                false_truss_detect += 1
                if (false_truss_detect < 90 and false_truss_detect%10 == 9):
                    send_data("4")    # 데이터 4 전송
                    print("1 화방을 찾지 못해 팔을 올립니다. send data = 4, UP")

                if(false_truss_detect > 100):
                    send_data("1")    # 정자세로 돌아가고 페이즈 10으로 귀환
                    print("1 화방을 감지하지 못해 페이즈 10으로 돌아갑니다. ")
                    false_truss_detect = 0
                    phase_num = 10
                    control_num = 0
                    
            # 2화방을 찾지 못한 경우 false_truss_detect을 증가하고, 이걸 5의 배수마다 확인하면 UP을 해 로봇팔을 위로 올림
            if(truss_coordinate == 1 and len(tom_truss) <= 1):
                false_truss_detect += 1
                if (false_truss_detect < 90 and false_truss_detect%10 == 9):
                    send_data("4")    # 데이터 9 전송
                    print("2화방을 찾지 못해 팔을 올립니다. send data = 4, UP")

                if(false_truss_detect > 100):
                    send_data("1")    # 정자세로 돌아가고 페이즈 10으로 귀환
                    print("2 화방을 감지하지 못해 페이즈 10으로 돌아갑니다. ")
                    false_truss_detect = 0
                    phase_num = 10
                    control_num = 0
                    
            
            # truss_coordinate == 0이면, 1화방을 제어한다.
            if(truss_coordinate == 0 and (control_num%3==1)):
                if len(tom_truss) > 0 and tom_truss[0] is not None: # 1화방 제어
                    
                    if (tom_truss[0]['x_center'] < 280):            # 화방이 중앙보다 왼쪽에 있는 경우
                        send_data("2")                              # 로봇팔을 왼쪽으로 움직임
                        print("LEFT")
                    if (tom_truss[0]['x_center'] > 320):            # 화방이 중앙보다 오른쪽에 있는 경우
                        send_data("3")                              # 로봇팔을 오른쪽으로 움직임
                        print("RIGHT")

                    if (tom_truss[0]['y_center'] < 220):            # 화방이 중앙보다 위에 있는 경우
                        send_data("4")                              # 로봇팔을 위로 움직임 
                        print("UP")
                    if (tom_truss[0]['y_center'] > 260):            # 화방이 중앙보다 아래에 있는 경우
                        send_data("5")                              # 로봇팔을 아래로 움직임
                        print("DOWN")

                    # 화방 위치 조정 완료 조건 : tom_truss가 1개이상이고, 가장 낮은 화방이 비어있지 않고, x,y중앙값에 위치한경우
                    if((tom_truss[0]['x_center'] >= 280 and tom_truss[0]['x_center'] <= 320) and 
                       (tom_truss[0]['y_center'] >= 220 and tom_truss[0]['y_center'] <= 260)): 
                        
                        send_data("6")    # 중앙 값 만족으로 대기
                        print("center")
                        control_num += 2  # 중앙 값 만족하면 카운트 시작
                        
                    if(control_num > 120):  # 화방 중앙에 위치시 만개꽃 조정 페이즈로 넘어감
                        print("4단계 페이즈로 넘어감")
                        false_truss_detect = 0
                        control_num = 0
                        phase_num = 4

                        
            # truss_coordinate == 1이면, 2화방을 제어한다.
            if(truss_coordinate == 1 and (control_num%3==1)):
                if len(tom_truss) > 1 and tom_truss[1] is not None: # 1화방 제어
                    
                    if (tom_truss[1]['x_center'] < 280):            # 화방이 중앙보다 왼쪽에 있는 경우
                        send_data("2")                              # 로봇팔을 왼쪽으로 움직임
                        print("LEFT")
                    if (tom_truss[1]['x_center'] > 320):            # 화방이 중앙보다 오른쪽에 있는 경우
                        send_data("3")                              # 로봇팔을 오른쪽으로 움직임
                        print("RIGHT")

                    if (tom_truss[1]['y_center'] < 220):            # 화방이 중앙보다 위에 있는 경우
                        send_data("4")                              # 로봇팔을 위로 움직임 
                        print("UP")
                    if (tom_truss[1]['y_center'] > 260):            # 화방이 중앙보다 아래에 있는 경우
                        send_data("5")                              # 로봇팔을 아래로 움직임
                        print("DOWN")

                    # 화방 위치 조정 완료 조건 : tom_truss가 1개이상이고, 가장 낮은 화방이 비어있지 않고, x,y중앙값에 위치한경우
                    if((tom_truss[1]['x_center'] >= 280 and tom_truss[1]['x_center'] <= 320) and 
                       (tom_truss[1]['y_center'] >= 220 and tom_truss[1]['y_center'] <= 260)): 
                        
                        send_data("6")    # 중앙 값 만족으로 대기
                        print("center")
                        control_num += 2  # 중앙 값 만족하면 카운트 시작
                        
                    if(control_num > 120):  # 화방 중앙에 위치시 만개꽃 조정 페이즈로 넘어감
                        print("4단계 페이즈로 넘어감")
                        false_truss_detect = 0
                        control_num = 0
                        phase_num = 4
                        


#=================================================== 만개꽃 개수 세기 및 조정 페이즈 ===========================================================

        # flower_control == 0   
        # flower_control == 1 
        # flower_control ==  2 
        

        elif(phase_num == 4):    
            print("phase_num = ", phase_num)
            print("flower_control = ",flower_control)
            print("control_num = ", control_num)
            print("noflower_count = ", noflower_count)
            print("len(flower_in_truss1) = ",len(flower_in_truss1))
            print("len(flower_in_truss2) = ",len(flower_in_truss2))
            
            # 화방 1개, 따라서 1화방만 감지하고 그에따라 판단하면됨
            # 화방 1개 안에 만개꽃이 2개있는가?를 감지한다. 화방 바운딩 박스내에 만개꽃 중심 좌표가 있는지를 판별하도록 한다.
            if(flower_control == 0):
                if len(flower_in_truss1) >= 2 :
                    control_num += 1
                    if(control_num<5) : 
                        print("대기")
                        send_data("6")
                    else:     # 만개꽃 개수 충족
                        print("1화방에 만개꽃 개수 충족, 분사페이즈로 넘어갑니다.")
                        control_num = 0
                        truss_control = 1  # 1화방만 있고, 1화방 분사해야함
                        phase_num = 5      # 분사 페이즈
                        noflower_count = 0    # 만개꽃 변수 초기화
                else : 
                    noflower_count += 1
                    if(noflower_count>30):
                        print("1화방에 만개꽃 개수 불충족, 경로주행으로 돌아갑니다.")
                        noflower_count = 0    # 만개꽃 변수 초기화
                        control_num = 0       # 컨트롤 변수 초기화 
                        noflower_count = 0
                        phase_num = 10        # 경로 주행 페이즈
                        
                        
            # 화방 2개, 1화방 조정
            elif(flower_control == 1):
                if len(flower_in_truss1) >= 2 :
                    control_num += 1
                    if(control_num<5) : 
                        send_data("6")
                    else:      # 만개꽃 위치 중앙으로 조정 완료
                        print("1화방에 만개꽃 개수 충족, 분사페이즈로 넘어갑니다.")
                        control_num = 0
                        truss_control = 2    # 2화방까지 있고, 1화방 분사해야함
                        flower_control = 2   # 다음 화방 조정은 2화방 조정으로 확인
                        truss_coordinate = 1 # 2화방 위치 조정을 하도록 설정
                        noflower_count = 0    # 만개꽃 변수 초기화
                        phase_num = 5        # 분사 페이즈
                else : 
                    noflower_count += 1
                    if(noflower_count>30):
                        print("1화방에 만개꽃 개수 불충족, 2화방 조정으로 넘어갑니다.")
                        truss_coordinate = 1
                        phase_num = 3         
                        flower_control = 2
                        control_num = 0
                        noflower_count = 0
                        truss_control = 1 # 2개의 화방중, 1화방 만개꽃 불충족, 2화방 탐지
                        
            # 화방 2개, 2화방 조절
            elif(flower_control == 2):
                if len(flower_in_truss2) >= 2 :
                    control_num += 1
                    if(control_num<10) : 
                        send_data("6")
                    else:  # 만개꽃 위치 중앙으로 조정 완료
                        print("2화방에 만개꽃 개수 충족, 분사페이즈로 넘어갑니다.")
                        phase_num = 5      # 분사 페이즈
                        truss_control = 1
                        control_num = 0
                        noflower_count = 0    # 만개꽃 변수 초기화
                        flower_control = 0
                else : 
                    noflower_count += 1
                    if(noflower_count>30):
                        print("2화방에 만개꽃 개수 불충족, 경로주행으로 돌아갑니다")
                        truss_coordinate = 0
                        phase_num = 10
                        flower_control = 0
                        noflower_count = 0    # 만개꽃 변수 초기화
                        control_num = 0

##=========================================================== 분사 페이즈 ===================================================================
        
        elif(phase_num == 5):   
            print("phase_num = ", phase_num)
            print("truss_control = ", truss_control)
            
            control_num += 1
            send_data("6")
            if(control_num == 5):
                send_data("7")    # 분사 
                print("분사")
            if(control_num> 20):
                if(truss_control == 1):    # truss_control == 1이면,  뭐가 되었든 화방 분사가 끝남
                    print("페이즈 10으로 넘어갑니다")
                    control_num = 0
                    phase_num = 10 
                    
                elif(truss_control == 2):  # truss_control == 2이면, 2화방이 중 1화방만 분사한거임
                    print("페이즈 3으로 돌아가 2화방 조정으로 돌아갑니다.")
                    control_num = 0
                    phase_num = 3 

#============================================경로 주행으로 복귀, 로봇 기본 자세로 바꾸고, 수위센서를 확인해야함 ==========================================
        
        elif(phase_num == 10): 
            
            print("phase_num = ", phase_num)
            print("control_num = ", control_num)
            
            control_num += 1
            if(control_num == 1 or control_num == 10):
                send_data("8")       # 기본자세로 복귀

                truss_control = 0   # 화방 개수 변수
                truss_coordinate = 0  # 화방 개수에 따른 위치 조정 변수
                flower_control = 0   # 만개꽃 페이즈 개수 변수
                noflower_count = 0   # 만개꽃 개수 카운트 변수, 2개이상 충족이 안될경우 다른 쪽으로 넘김
                final_truss_num = 0
                truss_num_is_0 = 0
                truss_num_is_1 = 0
                truss_num_is_2 = 0
                final_up_down = 0

            if(control_num == 20):
                send_data("0")    # 이동 명령
              
            if(control_num > 50):    # 분사가 끝난후 어느정도 걷고 나서 페이즈 변경
                phase_num = 0     

        cv2.imshow("Receiving Video", frame)
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break

    client_socket.send("o".encode())  #만약 값을 안준다면?, 디버깅용 코드
    time.sleep(0.01) # 0.1초 대기

client_socket.close()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 28.6ms
# Speed: 17.5ms preprocess, 28.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.1ms
# Speed: 0.0ms preprocess, 18.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.4ms
# Speed: 0.0ms preprocess, 22.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.7ms
# Speed: 1.0ms preprocess, 17.7ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.4ms
# Speed: 1.0ms preprocess, 19.4ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.8ms
# Speed: 1.0ms preprocess, 17.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.5ms
# Speed: 1.0ms preprocess, 18.5ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 24.6ms
# Speed: 0.0ms preprocess, 24.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 31.8ms
# Speed: 0.0ms preprocess, 31.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.4ms
# Speed: 1.0ms preprocess, 19.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.7ms
# Speed: 3.2ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 20.2ms
# Speed: 1.0ms preprocess, 20.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.8ms
# Speed: 1.0ms preprocess, 18.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 6.6ms preprocess, 19.2ms inference, 37.3ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 21.4ms
# Speed: 2.0ms preprocess, 21.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.4ms
# Speed: 3.3ms preprocess, 19.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.8ms
# Speed: 1.2ms preprocess, 19.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.1ms
# Speed: 2.5ms preprocess, 18.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.9ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 25.4ms
# Speed: 0.0ms preprocess, 25.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.9ms preprocess, 19.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 22.2ms
# Speed: 0.0ms preprocess, 22.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 0.0ms preprocess, 19.1ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 21.2ms
# Speed: 0.0ms preprocess, 21.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 21.7ms
# Speed: 0.0ms preprocess, 21.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 20.0ms
# Speed: 1.1ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 25.8ms
# Speed: 0.0ms preprocess, 25.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 14.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 0.0ms preprocess, 19.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.7ms
# Speed: 2.2ms preprocess, 19.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 1 car, 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 524.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 295.8, Y center: 111.82, Class: stem
# phase_num =  0
#
# 0: 480x640 1 car, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 303.9, Y center: 125.85, Class: stem
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# X center: 307.3, Y center: 132.48, Class: stem
# phase_num =  0
#
# 0: 480x640 1 car, 25.8ms
# Speed: 0.0ms preprocess, 25.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 310.84, Y center: 147.29, Class: stem
# phase_num =  1
# truss_num_is_0 =  1
# truss_num_is_1 =  0
# truss_num_is_2 =  0
# control_num =  1
#
# 0: 480x640 (no detections), 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  1
# truss_num_is_0 =  2
# truss_num_is_1 =  0
# truss_num_is_2 =  0
# control_num =  2
#
# 0: 480x640 1 person, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 449.14, Y center: 50.89, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  3
# truss_num_is_1 =  0
# truss_num_is_2 =  0
# control_num =  3
#
# 0: 480x640 1 person, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 451.24, Y center: 54.62, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  4
# truss_num_is_1 =  0
# truss_num_is_2 =  0
# control_num =  4
#
# 0: 480x640 1 person, 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# X center: 450.17, Y center: 57.1, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  5
# truss_num_is_1 =  0
# truss_num_is_2 =  0
# control_num =  5
#
# 0: 480x640 1 person, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 448.03, Y center: 60.69, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  6
# truss_num_is_1 =  0
# truss_num_is_2 =  0
# control_num =  6
#
# 0: 480x640 1 person, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 447.86, Y center: 65.11, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  0
# truss_num_is_2 =  0
# control_num =  7
#
# 0: 480x640 1 car, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bicycle, 1 car, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# X center: 346.86, Y center: 198.62, Class: stem
# X center: 491.68, Y center: 68.88, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  1
# truss_num_is_2 =  0
# control_num =  8
#
# 0: 480x640 1 person, 1 bicycle, 1 car, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 1 car, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 493.6, Y center: 71.3, Class: truss
# X center: 350.48, Y center: 199.38, Class: stem
# X center: 519.74, Y center: 87.6, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  2
# truss_num_is_2 =  0
# control_num =  9
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# X center: 456.75, Y center: 80.63, Class: tom_flower
# X center: 495.06, Y center: 77.35, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  3
# truss_num_is_2 =  0
# control_num =  10
#
# 0: 480x640 2 persons, 1 bicycle, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 496.1, Y center: 92.22, Class: truss
# X center: 458.2, Y center: 94.87, Class: tom_flower
# X center: 527.82, Y center: 109.02, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  4
# truss_num_is_2 =  0
# control_num =  11
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 455.96, Y center: 99.14, Class: tom_flower
# X center: 493.65, Y center: 97.88, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  5
# truss_num_is_2 =  0
# control_num =  12
#
# 0: 480x640 2 persons, 1 bicycle, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 28.3ms
# Speed: 1.0ms preprocess, 28.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 453.54, Y center: 102.74, Class: tom_flower
# X center: 491.32, Y center: 98.7, Class: truss
# X center: 524.88, Y center: 117.7, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  6
# truss_num_is_2 =  0
# control_num =  13
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 452.33, Y center: 103.32, Class: tom_flower
# X center: 490.08, Y center: 98.75, Class: truss
# X center: 523.55, Y center: 117.41, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  7
# truss_num_is_2 =  0
# control_num =  14
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# X center: 451.51, Y center: 102.56, Class: tom_flower
# X center: 489.13, Y center: 97.93, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  8
# truss_num_is_2 =  0
# control_num =  15
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 452.03, Y center: 100.3, Class: tom_flower
# X center: 489.27, Y center: 97.74, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  9
# truss_num_is_2 =  0
# control_num =  16
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 453.7, Y center: 97.36, Class: tom_flower
# X center: 491.55, Y center: 95.39, Class: truss
# X center: 524.48, Y center: 110.97, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  10
# truss_num_is_2 =  0
# control_num =  17
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# X center: 453.85, Y center: 96.48, Class: tom_flower
# X center: 491.64, Y center: 94.26, Class: truss
# X center: 523.73, Y center: 109.47, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  11
# truss_num_is_2 =  0
# control_num =  18
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 453.4, Y center: 96.27, Class: tom_flower
# X center: 490.74, Y center: 93.1, Class: truss
# X center: 523.21, Y center: 110.1, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  12
# truss_num_is_2 =  0
# control_num =  19
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 452.39, Y center: 96.74, Class: tom_flower
# X center: 490.79, Y center: 93.71, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  13
# truss_num_is_2 =  0
# control_num =  20
#
# 0: 480x640 2 persons, 1 bicycle, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 489.24, Y center: 92.14, Class: truss
# X center: 450.15, Y center: 96.95, Class: tom_flower
# X center: 520.99, Y center: 112.33, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  14
# truss_num_is_2 =  0
# control_num =  21
#
# 0: 480x640 1 person, 1 bicycle, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 488.83, Y center: 92.25, Class: truss
# X center: 449.22, Y center: 97.27, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  15
# truss_num_is_2 =  0
# control_num =  22
#
# 0: 480x640 1 person, 1 bicycle, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 451.71, Y center: 97.19, Class: tom_flower
# X center: 489.48, Y center: 93.57, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  16
# truss_num_is_2 =  0
# control_num =  23
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 489.29, Y center: 92.61, Class: truss
# X center: 451.84, Y center: 96.94, Class: tom_flower
# X center: 520.36, Y center: 110.67, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  17
# truss_num_is_2 =  0
# control_num =  24
#
# 0: 480x640 1 person, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 488.19, Y center: 92.22, Class: truss
# X center: 451.67, Y center: 95.61, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  18
# truss_num_is_2 =  0
# control_num =  25
#
# 0: 480x640 2 persons, 1 bicycle, 17.3ms
# Speed: 10.5ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 488.26, Y center: 90.8, Class: truss
# X center: 449.88, Y center: 94.82, Class: tom_flower
# X center: 518.12, Y center: 108.92, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  19
# truss_num_is_2 =  0
# control_num =  26
#
# 0: 480x640 1 person, 1 bicycle, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# X center: 486.24, Y center: 90.39, Class: truss
# X center: 448.74, Y center: 93.87, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  20
# truss_num_is_2 =  0
# control_num =  27
#
# 0: 480x640 1 person, 1 bicycle, 16.2ms
# Speed: 15.6ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 485.66, Y center: 88.42, Class: truss
# X center: 447.66, Y center: 92.4, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  21
# truss_num_is_2 =  0
# control_num =  28
#
# 0: 480x640 2 persons, 1 bicycle, 28.4ms
# Speed: 0.0ms preprocess, 28.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 485.41, Y center: 85.87, Class: truss
# X center: 447.75, Y center: 90.74, Class: tom_flower
# X center: 518.42, Y center: 101.7, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  22
# truss_num_is_2 =  0
# control_num =  29
# 2화방을 모두 찾을때까지 팔을 계속 올립니다.  0
# UP
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 483.34, Y center: 85.92, Class: truss
# X center: 446.43, Y center: 90.84, Class: tom_flower
# X center: 516.33, Y center: 102.65, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  23
# truss_num_is_2 =  0
# control_num =  30
#
# 0: 480x640 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# X center: 482.82, Y center: 87.71, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  24
# truss_num_is_2 =  0
# control_num =  31
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 483.98, Y center: 87.3, Class: truss
# X center: 517.08, Y center: 105.11, Class: tom_flower
# X center: 447.23, Y center: 91.63, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  25
# truss_num_is_2 =  0
# control_num =  32
#
# 0: 480x640 2 persons, 1 bicycle, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# X center: 485.29, Y center: 84.93, Class: truss
# X center: 517.88, Y center: 101.24, Class: tom_flower
# X center: 446.98, Y center: 90.54, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  26
# truss_num_is_2 =  0
# control_num =  33
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 15.6ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 451.26, Y center: 86.59, Class: tom_flower
# X center: 485.29, Y center: 81.14, Class: truss
# X center: 518.72, Y center: 97.44, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  27
# truss_num_is_2 =  0
# control_num =  34
#
# 0: 480x640 2 persons, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 447.58, Y center: 83.54, Class: tom_flower
# X center: 484.17, Y center: 79.99, Class: truss
# X center: 517.39, Y center: 94.19, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  28
# truss_num_is_2 =  0
# control_num =  35
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 484.77, Y center: 81.06, Class: truss
# X center: 446.35, Y center: 83.51, Class: tom_flower
# X center: 517.04, Y center: 91.48, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  29
# truss_num_is_2 =  0
# control_num =  36
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.0ms
# Speed: 1.1ms preprocess, 16.0ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
# X center: 447.53, Y center: 85.19, Class: tom_flower
# X center: 485.62, Y center: 82.24, Class: truss
# X center: 512.06, Y center: 95.74, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  30
# truss_num_is_2 =  0
# control_num =  37
#
# 0: 480x640 1 person, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# X center: 446.57, Y center: 80.74, Class: tom_flower
# X center: 482.3, Y center: 77.06, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  31
# truss_num_is_2 =  0
# control_num =  38
#
# 0: 480x640 1 person, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 444.04, Y center: 79.1, Class: tom_flower
# X center: 481.7, Y center: 73.44, Class: truss
# X center: 511.48, Y center: 90.1, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  32
# truss_num_is_2 =  0
# control_num =  39
#
# 0: 480x640 2 persons, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 442.83, Y center: 78.52, Class: tom_flower
# X center: 480.86, Y center: 73.93, Class: truss
# X center: 510.55, Y center: 89.6, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  33
# truss_num_is_2 =  0
# control_num =  40
#
# 0: 480x640 1 person, 1 bicycle, 18.1ms
# Speed: 3.0ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 475.44, Y center: 75.84, Class: truss
# X center: 439.93, Y center: 76.08, Class: tom_flower
# X center: 506.3, Y center: 87.86, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  34
# truss_num_is_2 =  0
# control_num =  41
#
# 0: 480x640 2 persons, 1 bicycle, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 432.47, Y center: 75.57, Class: tom_flower
# X center: 469.02, Y center: 74.61, Class: truss
# X center: 502.48, Y center: 86.04, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  35
# truss_num_is_2 =  0
# control_num =  42
#
# 0: 480x640 1 person, 1 bicycle, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 18.2ms
# Speed: 1.2ms preprocess, 18.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 436.42, Y center: 73.83, Class: tom_flower
# X center: 471.77, Y center: 73.98, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  36
# truss_num_is_2 =  0
# control_num =  43
#
# 0: 480x640 1 person, 1 bicycle, 17.1ms
# Speed: 2.3ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# X center: 472.72, Y center: 73.45, Class: truss
# X center: 438.24, Y center: 74.49, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  37
# truss_num_is_2 =  0
# control_num =  44
#
# 0: 480x640 1 person, 1 bicycle, 18.2ms
# Speed: 2.1ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 439.86, Y center: 74.7, Class: tom_flower
# X center: 474.58, Y center: 75.79, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  38
# truss_num_is_2 =  0
# control_num =  45
#
# 0: 480x640 1 person, 1 bicycle, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# X center: 439.92, Y center: 74.23, Class: tom_flower
# X center: 475.65, Y center: 75.26, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  39
# truss_num_is_2 =  0
# control_num =  46
#
# 0: 480x640 2 persons, 1 bicycle, 18.3ms
# Speed: 3.0ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# X center: 442.06, Y center: 72.06, Class: tom_flower
# X center: 510.11, Y center: 83.09, Class: tom_flower
# X center: 479.14, Y center: 70.88, Class: truss
# phase_num =  1
# truss_num_is_0 =  7
# truss_num_is_1 =  40
# truss_num_is_2 =  0
# control_num =  47
#
# 0: 480x640 1 person, 17.1ms
# Speed: 3.2ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 443.21, Y center: 70.95, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  40
# truss_num_is_2 =  0
# control_num =  48
#
# 0: 480x640 2 persons, 1 bicycle, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 444.19, Y center: 69.55, Class: tom_flower
# X center: 511.92, Y center: 80.82, Class: tom_flower
# X center: 482.84, Y center: 66.2, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  41
# truss_num_is_2 =  0
# control_num =  49
#
# 0: 480x640 2 persons, 1 bicycle, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.0ms
# Speed: 1.2ms preprocess, 16.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# X center: 443.34, Y center: 68.86, Class: tom_flower
# X center: 511.26, Y center: 78.49, Class: tom_flower
# X center: 481.85, Y center: 66.01, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  42
# truss_num_is_2 =  0
# control_num =  50
#
# 0: 480x640 2 persons, 1 bicycle, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 443.18, Y center: 69.18, Class: tom_flower
# X center: 511.01, Y center: 79.1, Class: tom_flower
# X center: 481.82, Y center: 67.61, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  43
# truss_num_is_2 =  0
# control_num =  51
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 445.75, Y center: 70.14, Class: tom_flower
# X center: 481.11, Y center: 67.98, Class: truss
# X center: 511.5, Y center: 80.17, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  44
# truss_num_is_2 =  0
# control_num =  52
#
# 0: 480x640 1 person, 1 bicycle, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 446.81, Y center: 71.3, Class: tom_flower
# X center: 483.09, Y center: 71.44, Class: truss
# X center: 508.05, Y center: 80.34, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  45
# truss_num_is_2 =  0
# control_num =  53
#
# 0: 480x640 1 person, 1 bicycle, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 479.66, Y center: 71.74, Class: truss
# X center: 442.62, Y center: 72.16, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  46
# truss_num_is_2 =  0
# control_num =  54
#
# 0: 480x640 2 persons, 1 bicycle, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 1 car, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 440.95, Y center: 72.88, Class: tom_flower
# X center: 476.88, Y center: 72.39, Class: truss
# X center: 509.98, Y center: 83.67, Class: tom_flower
# X center: 343.14, Y center: 191.45, Class: stem
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  47
# truss_num_is_2 =  0
# control_num =  55
#
# 0: 480x640 1 person, 1 bicycle, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 1 car, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 439.79, Y center: 72.5, Class: tom_flower
# X center: 474.38, Y center: 74.71, Class: truss
# X center: 341.45, Y center: 198.73, Class: stem
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  48
# truss_num_is_2 =  0
# control_num =  56
#
# 0: 480x640 1 person, 1 bicycle, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 439.42, Y center: 71.7, Class: tom_flower
# X center: 473.97, Y center: 74.29, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  49
# truss_num_is_2 =  0
# control_num =  57
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 440.15, Y center: 71.9, Class: tom_flower
# X center: 474.97, Y center: 73.18, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  50
# truss_num_is_2 =  0
# control_num =  58
#
# 0: 480x640 1 person, 1 bicycle, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 440.75, Y center: 70.37, Class: tom_flower
# X center: 476.11, Y center: 69.65, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  51
# truss_num_is_2 =  0
# control_num =  59
# 2화방을 모두 찾을때까지 팔을 계속 올립니다.  1
# UP
#
# 0: 480x640 1 person, 1 bicycle, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# X center: 440.97, Y center: 68.63, Class: tom_flower
# X center: 474.86, Y center: 69.28, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  52
# truss_num_is_2 =  0
# control_num =  60
#
# 0: 480x640 2 persons, 1 bicycle, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 441.33, Y center: 68.54, Class: tom_flower
# X center: 509.74, Y center: 78.13, Class: tom_flower
# X center: 476.68, Y center: 68.27, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  53
# truss_num_is_2 =  0
# control_num =  61
#
# 0: 480x640 1 person, 1 bicycle, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# X center: 441.15, Y center: 67.67, Class: tom_flower
# X center: 476.25, Y center: 70.26, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  54
# truss_num_is_2 =  0
# control_num =  62
#
# 0: 480x640 1 person, 1 bicycle, 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 15.7ms
# Speed: 1.0ms preprocess, 15.7ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 439.97, Y center: 65.77, Class: tom_flower
# X center: 477.2, Y center: 68.94, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  55
# truss_num_is_2 =  0
# control_num =  63
#
# 0: 480x640 1 person, 1 bicycle, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 441.34, Y center: 67.69, Class: tom_flower
# X center: 476.47, Y center: 67.68, Class: truss
# X center: 509.38, Y center: 77.35, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  56
# truss_num_is_2 =  0
# control_num =  64
#
# 0: 480x640 1 person, 1 bicycle, 17.2ms
# Speed: 3.0ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 477.59, Y center: 65.8, Class: truss
# X center: 509.8, Y center: 77.4, Class: tom_flower
# X center: 442.75, Y center: 67.52, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  57
# truss_num_is_2 =  0
# control_num =  65
#
# 0: 480x640 2 persons, 1 bicycle, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 441.61, Y center: 67.48, Class: tom_flower
# X center: 478.09, Y center: 65.71, Class: truss
# X center: 509.53, Y center: 77.07, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  58
# truss_num_is_2 =  0
# control_num =  66
#
# 0: 480x640 2 persons, 1 bicycle, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 441.23, Y center: 67.51, Class: tom_flower
# X center: 509.7, Y center: 77.44, Class: tom_flower
# X center: 476.63, Y center: 68.33, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  59
# truss_num_is_2 =  0
# control_num =  67
#
# 0: 480x640 2 persons, 1 bicycle, 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 442.74, Y center: 67.47, Class: tom_flower
# X center: 480.06, Y center: 64.58, Class: truss
# X center: 509.89, Y center: 77.53, Class: tom_flower
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  60
# truss_num_is_2 =  0
# control_num =  68
#
# 0: 480x640 2 persons, 1 bicycle, 18.0ms
# Speed: 2.3ms preprocess, 18.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 18.0ms
# Speed: 0.9ms preprocess, 18.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 443.73, Y center: 67.65, Class: tom_flower
# X center: 510.87, Y center: 77.66, Class: tom_flower
# X center: 480.78, Y center: 64.95, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  61
# truss_num_is_2 =  0
# control_num =  69
#
# 0: 480x640 2 persons, 1 bicycle, 1 car, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 1 car, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 510.97, Y center: 78.12, Class: tom_flower
# X center: 444.5, Y center: 67.63, Class: tom_flower
# X center: 482.92, Y center: 65.45, Class: truss
# X center: 349.68, Y center: 185.98, Class: stem
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  62
# truss_num_is_2 =  0
# control_num =  70
#
# 0: 480x640 1 person, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bicycle, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 445.0, Y center: 67.95, Class: tom_flower
# X center: 480.77, Y center: 65.82, Class: truss
# phase_num =  1
# truss_num_is_0 =  8
# truss_num_is_1 =  63
# truss_num_is_2 =  0
# control_num =  71
#
# 0: 480x640 2 persons, 1 bicycle, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bicycle, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# X center: 443.15, Y center: 68.22, Class: tom_flower
# X center: 482.51, Y center: 64.84, Class: truss
# X center: 511.43, Y center: 77.74, Class: tom_flower
# phase_num =  1
# ...
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.2ms
# Speed: 1.0ms preprocess, 20.2ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 1.2ms preprocess, 16.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.5ms
# Speed: 2.0ms preprocess, 19.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.2ms
# Speed: 1.2ms preprocess, 17.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 3.0ms preprocess, 19.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 3.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 12.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 2.2ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.2ms
# Speed: 3.0ms preprocess, 17.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.2ms
# Speed: 1.0ms preprocess, 22.2ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.6ms
# Speed: 0.7ms preprocess, 25.6ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 1 car, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# X center: 214.62, Y center: 292.29, Class: stem
# phase_num =  0
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 27.3ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.3ms
# Speed: 1.0ms preprocess, 17.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 0.0ms preprocess, 18.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
#
# 0: 480x640 (no detections), 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# phase_num =  0
